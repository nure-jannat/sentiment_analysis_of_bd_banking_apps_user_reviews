# %%
pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
from  google_play_scraper import app, Sort, reviews_all

# %%
import os

# %%
# BRAC Bank
astha_reviews = reviews_all(
    'com.bracbank.astha', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST
)
astha_df = pd.json_normalize(astha_reviews)

# %%
astha_df = pd.json_normalize(astha_reviews)

# %%
astha_df
# Out:
#                                   reviewId              userName  \
# 0     c54443b1-a61a-40cb-8b3a-6a9c703dea73         A Google user
# 1     8a3e782c-742e-4d68-a789-4e6a02a2bd41         A Google user
# 2     117c232a-7e86-43e1-8ebc-53db68e2081e         A Google user
# 3     c3c6d191-0171-45bf-a4a4-f41359433632         A Google user
# 4     8f2022ed-4eca-4fdd-abde-5aac2a2e985e         A Google user
# ...                                    ...                   ...
# 5968  239b19eb-b55b-4223-8a57-f78468f0c389                diaify
# 5969  8f5928f1-97fe-450f-bb54-88312bbcfdc2  Sajib Raihan Russell
# 5970  00fc0c66-2df4-4842-beb2-52465e30a0d1    Golam Zelani Shuvo
# 5971  06838eb0-8d9a-4a8c-b5e8-2540c204f716  Faiad Iftikhar Rafee
# 5972  bda4245d-ec6b-4497-818b-b7935c239fc1  Bishwajit Purkaystha
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
astha_df.to_csv('/content/drive/My Drive/banking_review_spl3/astha_reviews.csv', index=False)

# %%
agrani_reviews = reviews_all(
    'net.celloscope.ib_mobile_app', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
agrani_df = pd.json_normalize(agrani_reviews)

# %%
agrani_df
# Out:
#                                   reviewId       userName  \
# 0     d1308d80-ad02-40e4-ae05-efade6a4c3dc  A Google user
# 1     599eb84d-ed05-4e9d-bdaa-2a1183d4d9d8  A Google user
# 2     dd839bed-81f2-43ec-b38b-cc2e41d092f4  A Google user
# 3     dabe3886-9e7a-46fb-9689-3edba0c60d32  A Google user
# 4     cc8c4c37-29b6-498b-948e-1016153960f3  A Google user
# ...                                    ...            ...
# 2164  0a45150d-6999-49d6-a24c-6acbced001dd  A Google user
# 2165  1c0fd84d-a049-441a-9cb8-003338a0a513  A Google user
# 2166  fb9dbd93-2423-4ee9-a5d2-444de7328fb5  A Google user
# 2167  6d8b058c-b2f9-4c41-8531-e6db37ba51e9  A Google user
# 2168  fda46f0f-84d1-4d23-871b-9c304a7d9404  A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
agrani_df.to_csv('/content/drive/My Drive/banking_review_spl3/agran_reviews.csv', index=False)

# %%
# Islami Bank
ibbl_reviews = reviews_all(
    'com.ionicframework.icellular894076', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
ibbl_df = pd.json_normalize(ibbl_reviews)

# %%
ibbl_df
# Out:
#                                   reviewId       userName  \
# 0     058dcd14-2a3e-4170-a9fd-c3c5f030da0e  A Google user
# 1     3569d5ae-e6b4-4083-bb0b-f04cc0a3a270  A Google user
# 2     a23e3b6c-fce7-4f84-a5a3-084fb20d0dc0  A Google user
# 3     b0f0853c-8d66-46ff-a594-96d8b31a4f7e  A Google user
# 4     e087091b-00b3-419d-85a8-9f24bab69ee2  A Google user
# ...                                    ...            ...
# 4363  6a57bb56-182a-4ba2-9dae-926c7388311c  A Google user
# 4364  3e9583fc-571d-4d55-ae1c-fc1471a7513e  A Google user
# 4365  079f5a07-94cd-467e-80dd-34c3f2a2655d  A Google user
# 4366  e72fa263-186e-4ac7-84b9-8f6e00ece17d  A Google user
# 4367  822bcd09-100b-400f-a245-df67ba5c9fcd  A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
ibbl_df.to_csv('/content/drive/My Drive/banking_review_spl3/ibbl_reviews.csv', index=False)

# %%
# City Bank
citytouch_reviews = reviews_all(
    'com.ionicframework.icellular894076', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)

citytouch_df = pd.json_normalize(citytouch_reviews)

# %%
citytouch_df
# Out:
#                                   reviewId       userName  \
# 0     058dcd14-2a3e-4170-a9fd-c3c5f030da0e  A Google user
# 1     3569d5ae-e6b4-4083-bb0b-f04cc0a3a270  A Google user
# 2     a23e3b6c-fce7-4f84-a5a3-084fb20d0dc0  A Google user
# 3     b0f0853c-8d66-46ff-a594-96d8b31a4f7e  A Google user
# 4     e087091b-00b3-419d-85a8-9f24bab69ee2  A Google user
# ...                                    ...            ...
# 4363  6a57bb56-182a-4ba2-9dae-926c7388311c  A Google user
# 4364  3e9583fc-571d-4d55-ae1c-fc1471a7513e  A Google user
# 4365  079f5a07-94cd-467e-80dd-34c3f2a2655d  A Google user
# 4366  e72fa263-186e-4ac7-84b9-8f6e00ece17d  A Google user
# 4367  822bcd09-100b-400f-a245-df67ba5c9fcd  A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
citytouch_df.to_csv('/content/drive/My Drive/banking_review_spl3/citytouch_reviews.csv', index=False)

# %%
# Eastern Bank Limited
ebl_reviews = reviews_all(
    'com.ebl.skybanking', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
ebl_df = pd.json_normalize(ebl_reviews)

# %%
ebl_df
# Out:
#                                   reviewId                userName  \
# 0     efb15aa9-d5ad-4005-843f-fe015528ff1b              Yasin Khan
# 1     e1a363f3-f6dc-48e3-9992-663d792b21ab           mousumi akter
# 2     0ba0beaf-4cf3-48b3-9b2d-4cddcc6b6bee           A Google user
# 3     8d035f81-6a16-4b37-a65c-cd9ef433279f              Omar Faruk
# 4     2d827ae7-2c86-4a30-b602-5df31fc0a828        ANJAN KUMER NATH
# ...                                    ...                     ...
# 1862  0aae9f92-353e-4899-aa31-d39c55730dc7              Imam Hasan
# 1863  05281f0f-33bf-4bb3-9252-ee8bb3558bbc           Rifat's Dairy
# 1864  25d41fd9-f8ba-4285-8b10-e9bbe4e44c8b  Abdullah al ahad Limon
# 1865  4a27b7ab-ae8b-4ef4-8a2d-cb22b0f4929d         Mars Astronauts
# 1866  df75b93a-a799-4fc7-a6c0-5811af507069            NAZRUL ISLAM
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
ebl_df.to_csv('/content/drive/My Drive/banking_review_spl3/ebl_reviews.csv', index=False)

# %%
# Prime Bank
pb_reviews = reviews_all(
    'bd.com.primebank.pib.altitudemobile', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
pb_df = pd.json_normalize(pb_reviews)

# %%
pb_df
# Out:
#                                  reviewId                         userName  \
# 0    fb11827d-d0f7-488a-94f3-ac02a598b90f               Md Sadikur Rohoman
# 1    34c604e8-f85e-4c99-9d15-4e62adf18552  Mohammad Mosharraf Hossain Khan
# 2    4526e51e-4b3b-4a43-9f5b-7931fe999ca8                 Sheikh Suman Ali
# 3    36c9f49a-5bd0-4def-9bd8-8ed0e16c40e5                         md kanon
# 4    bd5be7c8-b7d4-4361-8dce-f1ef24c1d698                 MD.ATIQUR RAHMAN
# ..                                    ...                              ...
# 848  074e50af-83b4-4b29-923f-dbb0b5f8760e                    A Google user
# 849  9053dcc5-1ace-48fe-9c64-5dc24d7dcf41                    A Google user
# 850  17303a08-900e-42e3-810f-6e2fcb215016                    A Google user
# 851  68025a44-2586-4cd4-94fa-ab7c82e624aa                    A Google user
# 852  6afc1424-a8d7-4f32-a45c-f6f518108354                    A Google user
#
#                                              userImage  \
# ...

# %%
pb_df.to_csv('/content/drive/My Drive/banking_review_spl3/prime_reviews.csv', index=False)

# %%
# AB Bank Limited
ab_reviews = reviews_all(
    'com.brainstation23.ib.abbl', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
ab_df = pd.json_normalize(ab_reviews)

# %%
ab_df
# Out:
#                                   reviewId               userName  \
# 0     28dcd56c-4765-47ff-916d-5dc574feb9ae               md masud
# 1     e25d9e94-f57f-4117-8ac3-41e0674419e3           washif ahmed
# 2     6f4a4789-6185-45e1-928e-e4148a5bb310        Md.Shoaib Hasan
# 3     a3652ea7-8932-4061-a64b-5eca76f7a623  Mahtabuzzaman Shabbir
# 4     173dbcb2-ca0b-415a-8f6c-fcb643a1978f     এসো নতুন কিছু শিখি
# ...                                    ...                    ...
# 1007  6f411b5b-a251-47e8-919d-64bcd67fdc5a          A Google user
# 1008  794291d1-fa97-4404-be00-f70f136ebd0e          A Google user
# 1009  fc192082-3c2f-40f7-99ed-fe817e4d9949          A Google user
# 1010  c9fd90fb-f8bd-4a71-8bf6-e809e1d87d2c          A Google user
# 1011  5376faa9-033b-45ce-ade4-39c1a22edd4e          A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
ab_df.to_csv('/content/drive/My Drive/banking_review_spl3/ab_bank.csv', index=False)

# %%
# Owned by Islami Bank Bangladesh Limited
cellfin_reviews = reviews_all(
    'com.ibbl.cellfin', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
cellfin_df = pd.json_normalize(cellfin_reviews)

# %%
cellfin_df
# Out:
#                                    reviewId       userName  \
# 0      ab4c3aab-aad5-426d-a099-06d32988fa40  A Google user
# 1      eecc7d9c-bcd8-4ac3-bad4-bbe7882225ce  A Google user
# 2      d140bfc7-71cc-4371-8cd3-e62d9ed75d1f  A Google user
# 3      479c52ba-9014-43b2-8ac0-3a1599731e8d  A Google user
# 4      9a77fb3b-bce2-4fb8-80c0-99a25d62ac47  A Google user
# ...                                     ...            ...
# 15200  362f4261-aa8f-4517-908b-6a4b0e17352f  A Google user
# 15201  ed35a69d-c730-4873-8d02-8543baa32193  A Google user
# 15202  707c3d4d-c5b7-4854-8cfc-584137f86afa  A Google user
# 15203  e0c26936-c014-4b3d-b065-04b7825a4d96  A Google user
# 15204  1552398e-d140-457a-8acc-50bc1880f264  A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
cellfin_df.to_csv('/content/drive/My Drive/banking_review_spl3/cellfin.csv', index=False)

# %%
# Dutch Bangla Bank
nexus_reviews = reviews_all(
    'com.dbbl.nexus.pay', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
nexus_df = pd.json_normalize(nexus_reviews)

# %%
nexus_df
# Out:
#                                    reviewId       userName  \
# 0      3e03ca2f-b8e9-4ae5-9c3d-854f16196038  A Google user
# 1      f61677d7-147e-40d7-a2b3-486262adf9fa  A Google user
# 2      00a4a78a-137c-4032-a004-620c734ba20f  A Google user
# 3      efa46b18-aae0-4843-a92a-5944f2113b6e  A Google user
# 4      8b3a6877-448d-405b-88e7-f626aa7919e8  A Google user
# ...                                     ...            ...
# 28429  dfeb12a4-e1fd-49ea-9f16-19238c529d2c  A Google user
# 28430  80bbd833-ba80-48e9-9538-29f430d351d9  A Google user
# 28431  798e1d6b-22fd-4568-b4d9-75086ca9401c  A Google user
# 28432  eabe008d-5238-49d4-83b3-c111e3adc06b  A Google user
# 28433  fe5a037b-c237-48cc-8940-f996c536ba39  A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
nexus_df.to_csv('/content/drive/My Drive/banking_review_spl3/nexus_pay.csv', index=False)

# %%
# Mutual Trust Bank
mtb_reviews = reviews_all(
    'com.mtb.mobilebanking', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
mtb_df = pd.json_normalize(mtb_reviews)

# %%
mtb_df
# Out:
#                                   reviewId           userName  \
# 0     dd202004-2385-4509-a41e-b788fb486c3b       Ziaull Hoque
# 1     11fb0322-5be9-4e0e-ad5a-f2cc89e9361e        Mira Khatun
# 2     57f5d8d8-7788-45de-ba4f-2acfb340ea51  Md Monoar Hossain
# 3     c8642991-bafc-47d7-96cf-933577655d47         Semo Akter
# 4     c9794d5a-b923-456b-94af-4afb6efcf440        Nasir Uddin
# ...                                    ...                ...
# 1656  ea4a1196-0144-49cb-ba46-1c33ea376978      A Google user
# 1657  44ec08eb-f761-41e4-aca2-822242d0cc88      A Google user
# 1658  8c736d64-4253-4ce4-8d22-8cab86833627      A Google user
# 1659  4455a76a-92fc-47f5-b8f0-ddcc827f1d74      A Google user
# 1660  739fe00e-df9f-411c-98d8-e4423137dee5      A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
mtb_df.to_csv('/content/drive/My Drive/banking_review_spl3/mutual_trust_bank.csv', index=False)

# %%
# Standard Chartered Bank
sc_reviews = reviews_all(
    'com.sc.mobilebanking.bd', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
sc_df = pd.json_normalize(sc_reviews)

# %%
sc_df
# Out:
#                                   reviewId            userName  \
# 0     53124f37-1462-44b4-9254-59bd6ac38dc5         Safayet Ema
# 1     ad46aa14-53d0-410e-aabc-48e327887c38      Ejaz Chowdhury
# 2     5c579ae9-25b7-49b7-899e-3981566aa3fd        mahmud sakib
# 3     eee886f1-0ace-4186-89e6-b07f05c60883     Nayeemul Jannat
# 4     6eb01637-4c53-46c8-b20c-5984ff69e95a  Md Maksudul Hassan
# ...                                    ...                 ...
# 1963  eb166133-5439-4951-92f5-e1688e641250       A Google user
# 1964  a27e58ca-09ae-4463-9cb8-a40fb20c7aa0       A Google user
# 1965  7da94df7-0e60-4043-9c6c-646ca6528bf5       A Google user
# 1966  aaf47ccb-4ea4-4536-932d-01c617e0d577       A Google user
# 1967  d7704abb-8ad9-423a-946b-a70074682651       A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
sc_df.to_csv('/content/drive/My Drive/banking_review_spl3/standard_chartered_bank.csv', index=False)

# %%
# Dhaka Bank
db_reviews = reviews_all(
    'com.dbl.goplus', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
db_df = pd.json_normalize(db_reviews)

# %%
db_df
# Out:
#                                 reviewId            userName  \
# 0   579da5cf-b68b-4860-949c-8f4fba16f51c    Pronob Kumar Dey
# 1   0b5a3324-d51a-4284-85b7-4c37e26de27c  ASIF MAHMUD JASHIM
# 2   1490a946-20e3-4d7e-b79b-e58dc87f34a1         Anik Sarker
# 3   4ee14dc2-9cf4-4328-9127-286dc7b11aac         Munir Hasan
# 4   d32b1928-ab1b-47a6-aa74-15d9cec94ba5       Tanzina Islam
# ..                                   ...                 ...
# 64  29a4efa6-5d55-4d27-a447-9f793d61818b     Sharanon Chakma
# 65  c92df1bb-2a62-4e4e-8b88-6bca4fd288dc     md zihadul Alam
# 66  99e46a1d-a7e8-4dfd-afc7-194c7b861447        Sujan Mullah
# 67  2fd388e2-5ec2-442c-a47c-66e89d766d13   Nafis Islam Kabbo
# 68  ff5a66a4-65ec-44e2-af62-e4a677b9b96c       Lutfur Rahman
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a-/ALV-U...
# 1   https://play-lh.googleusercontent.com/a-/ALV-U...
# 2   https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
db_df.to_csv('/content/drive/My Drive/banking_review_spl3/dhaka_bank.csv', index=False)

# %%
# Sonali Bank Limited
sb_reviews = reviews_all(
    'bd.com.sonalibank.sw', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
sb_df = pd.json_normalize(sb_reviews)

# %%
sb_df
# Out:
#                                   reviewId       userName  \
# 0     89474e1f-9b6c-450b-9448-8bf9da7b1840  A Google user
# 1     4e48d792-0ad8-4c31-af21-2b5c6f85b519  A Google user
# 2     5d68d6eb-dcb9-4774-a3c7-b9d797d6e9a9  A Google user
# 3     07197ed8-1bf2-4343-ad94-038acf5d2182  A Google user
# 4     33055658-6586-4fac-80ee-c0c1d8283d65  A Google user
# ...                                    ...            ...
# 6650  18a74fff-c4e3-4e1d-9369-59b2097f0ee3  A Google user
# 6651  2e1990ce-5d21-4295-9f06-2ca8fd238216  A Google user
# 6652  bc949d44-0ed6-496f-b190-b06e1c046f62  A Google user
# 6653  3f7af1f9-15ab-4037-92d2-4fd462626c25  A Google user
# 6654  383dc873-f954-46f9-bbd3-bf133929d8e1  A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
sb_df.to_csv('/content/drive/My Drive/banking_review_spl3/sonali_bank.csv', index=False)

# %%
# Prime Bank PLC
pb_reviews = reviews_all(
    'bd.com.primebank.pib.altitudemobile', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
pb_df = pd.json_normalize(pb_reviews)

# %%
pb_df
# Out:
#                                  reviewId                         userName  \
# 0    fb11827d-d0f7-488a-94f3-ac02a598b90f               Md Sadikur Rohoman
# 1    34c604e8-f85e-4c99-9d15-4e62adf18552  Mohammad Mosharraf Hossain Khan
# 2    4526e51e-4b3b-4a43-9f5b-7931fe999ca8                 Sheikh Suman Ali
# 3    36c9f49a-5bd0-4def-9bd8-8ed0e16c40e5                         md kanon
# 4    bd5be7c8-b7d4-4361-8dce-f1ef24c1d698                 MD.ATIQUR RAHMAN
# ..                                    ...                              ...
# 848  074e50af-83b4-4b29-923f-dbb0b5f8760e                    A Google user
# 849  9053dcc5-1ace-48fe-9c64-5dc24d7dcf41                    A Google user
# 850  17303a08-900e-42e3-810f-6e2fcb215016                    A Google user
# 851  68025a44-2586-4cd4-94fa-ab7c82e624aa                    A Google user
# 852  6afc1424-a8d7-4f32-a45c-f6f518108354                    A Google user
#
#                                              userImage  \
# ...

# %%
pb_df.to_csv('/content/drive/My Drive/banking_review_spl3/prime_bank.csv', index=False)

# %%
# EXIM Bank PLC
exim_reviews = reviews_all(
    'com.eximbankbd.eWallet', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
exim_df = pd.json_normalize(exim_reviews)

# %%
exim_df
# Out:
#                                  reviewId                userName  \
# 0    d2c34a18-2c84-4378-b54e-808b7ae5b194  MOHAMMAD HUMAYON KOBIR
# 1    306d6544-1fb7-4f31-83e8-02e682a029e0         Askar Khan Amon
# 2    ed08bee9-963c-4630-b8de-2a20fb53a16e           Alone Monarch
# 3    8400bdc2-4ee5-4f57-b921-bc5da596378c              ISMAIL DXB
# 4    adc078ca-0bdb-47f9-b9af-04e3b16dbf46        Jovanni Emiliano
# ..                                    ...                     ...
# 153  fa6bdf5b-80e6-4e55-b019-564a1e9e1b51     Md. Mahbubur Rahman
# 154  467b01a3-042f-4c5c-b842-5f8ebea0222e        Md. Mehedi Hasan
# 155  875a85ac-3a01-472b-aeed-54a2ac064e03           Apurbo Ahamed
# 156  603faae0-e831-44cd-93bd-15c615664b50        MOHAMMAD AL NOOR
# 157  b80fc53b-c614-47a4-8768-24cd7ec8765c             Saifs World
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
exim_df.to_csv('/content/drive/My Drive/banking_review_spl3/exim_bank.csv', index=False)

# %%
# Meghna Bank PLC
meghna_reviews = reviews_all(
    'com.cibl.meghnabankltd', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
meghna_df = pd.json_normalize(meghna_reviews)

# %%
meghna_df
# Out:
#                                  reviewId            userName  \
# 0    fe33be60-3fd3-4714-9aa0-f37e305040ec          maya begum
# 1    cda7a703-52fe-4466-aebe-e5974972aecd      Ehasanul Haque
# 2    3479a31a-1c10-4eb7-9544-623f345c42bf      Tanjilul Niloy
# 3    44aea7cb-3383-45f7-8f6d-9125f0ea8d84          IMRAN KHAN
# 4    aa9f875f-0e39-4498-b6e5-618c1c0fda6f      MAHIM TABASSUM
# ..                                    ...                 ...
# 156  16bf4e8a-04ce-42ce-9e0c-bfbbf124b433  Md. Hasanur Rahman
# 157  7a3b4f27-c3ee-4afb-acee-f11c03f10da8   Md. Jahirul Islam
# 158  16b11ee7-fc5d-46d1-95d5-101bd7d30856  Md. Sarowar Hossen
# 159  4cfb1fb4-bd38-4ec7-aa56-257b556fe66f     akm arifuzzaman
# 160  725f6121-0c9c-4edf-bd3a-a51e669ebaa3       Rokibul Islam
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/ACg8oc...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
meghna_df.to_csv('/content/drive/My Drive/banking_review_spl3/meghna_bank.csv', index=False)

# %%
# Bank Asia PLC
asia_reviews = reviews_all(
    'eraapps.bankasia.bdinternetbanking.apps', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
asia_df = pd.json_normalize(asia_reviews)

# %%
asia_df
# Out:
#                                   reviewId          userName  \
# 0     8fb2f888-e591-48e4-8a80-9bd2dbe3da77      Google Pixel
# 1     4520e961-dda4-4b13-9b49-9c4f687cf4c2   Md Rifat Mahmud
# 2     4b6c0731-b648-4c48-8d47-d424cf728eee    Alamin Pramink
# 3     d7f42400-d4a0-4f8d-96e2-a9bc524e719b         Purnopama
# 4     607945b5-7be7-4241-8bc0-3c2708ba7ff4  MD KHALED MAHMUD
# ...                                    ...               ...
# 1966  75703010-f5af-47ea-ad4d-81fb7a860ec8     A Google user
# 1967  c6c236c0-242a-45c3-89f7-061a37c69bd7     A Google user
# 1968  1140c2a6-9808-4c35-bf5e-9c4e5a17cec3     A Google user
# 1969  186c15d0-cf87-4962-81c2-904edf112f9a     A Google user
# 1970  2f4a08bd-9c2f-4e37-9d96-833490500883     A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
asia_df.to_csv('/content/drive/My Drive/banking_review_spl3/asia_bank.csv', index=False)

# %%
# United Commercial Bank Limited
unet_reviews = reviews_all(
    'bd.com.ucb.unet', sleep_milliseconds=0, lang='en', country='BD', sort=Sort.NEWEST)
unet_df = pd.json_normalize(unet_reviews)

# %%
unet_df
# Out:
#                                   reviewId               userName  \
# 0     248b532d-0862-4980-b29a-428e369c2780       Md Ruman Hossain
# 1     cdcc08f8-e592-412d-b859-d7dcec4f0f2f  MD.RABIUL HASAN Sayed
# 2     4c1746b6-b722-4429-82cb-ebc6b2b250a5              Uzzal Mia
# 3     3559399c-eb7b-497c-8885-548e345027f8         Shaffat Hossan
# 4     dac91c84-8c2a-4758-99b7-bb152dfa07b6                  SURZO
# ...                                    ...                    ...
# 2041  399c9897-1dac-42b7-adf7-6752735c37b8          A Google user
# 2042  5ac508ae-9905-4d68-bcc0-dddd465f39b4          A Google user
# 2043  d20e7660-3f60-48c5-8f9b-ada1cc1b57de          A Google user
# 2044  8ed1848b-41b9-49b8-b3c7-ac90d3cbf8a5          A Google user
# 2045  7aabe66c-5c4f-46f0-8fd3-c83b854ca3ec          A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
unet_df.to_csv('/content/drive/My Drive/banking_review_spl3/ucb_bank.csv', index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/agran_reviews.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "Agrani Smart Banking App"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', index=False)

# %%
df.size
# Out:
# 8676

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/ucb_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "United Commercial Bank Limited"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/astha_reviews.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "BRAC Bank Astha"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/cellfin.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "CellFin"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/citytouch_reviews.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "Citytouch"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/dhaka_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "DBL Go"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/ebl_reviews.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "Eastern Bank Mobile Banking"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/ibbl_reviews.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "IBBL iSmart"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/mutual_trust_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "MTB Neo"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/nexus_pay.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "NexusPay"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/prime_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "MyPrime"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/sonali_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "Sonali e-Wallet"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/standard_chartered_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "SC Mobile Bangladesh"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/asia_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "Bank Asia PLC"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/exim_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "Exim Bank"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/meghna_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "Meghna Bank"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
file_path = "/content/drive/My Drive/banking_review_spl3/ab_bank.csv"
df = pd.read_csv(file_path, usecols=['content', 'score', 'at'])
df['app_name'] = "AB Direct Internet Banking"
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', mode='a', header=False, index=False)

# %%
df = pd.read_csv("/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv")

# %%
app_wise_counts = df['app_name'].value_counts()
app_wise_counts
# Out:
# app_name
# NexusPay                       28434
# CellFin                        15205
# Sonali e-Wallet                 6655
# BRAC Bank Astha                 5973
# Citytouch                       4368
# IBBL iSmart                     4368
# Agrani Smart Banking App        2169
# Unet                            2046
# Bank Asia SMART App             1971
# SC Mobile Bangladesh            1968
# Eastern Bank Mobile Banking     1867
# MTB Neo                         1661
# AB Direct Internet Banking      1012
# MyPrime                          853
# i-Banking                        161
# EXIM aiser                       158
# DBL Go                            69
# Name: count, dtype: int64

# %%
# Assuming your DataFrame is called df and it has a column 'app_name'
df['app_name'] = df['app_name'].replace({
    'Meghna Bank': 'i-Banking',
    'Exim Bank': 'EXIM aiser',
    'United Commercial Bank Limited': 'Unet',
    'Bank Asia PLC': 'Bank Asia SMART App'
})

# %%
df = df.rename(columns={'content': 'review_text', 'score': 'rating', 'at': 'review_time'})

# %%
df.head()
# Out:
#                                          review_text  rating  \
# 0  faltu app mobile reset dea AJ 1 sapta dore ghu...       1
# 1                                   not good not bad       5
# 2                                               nice       5
# 3                    really helpful app nice working       4
# 4                                                 ok       5
#
#            review_time                  app_name
# 0  2025-04-09 08:35:06  Agrani Smart Banking App
# 1  2025-04-09 03:08:43  Agrani Smart Banking App
# 2  2025-04-06 03:26:31  Agrani Smart Banking App
# 3  2025-04-02 19:45:17  Agrani Smart Banking App
# 4  2025-04-02 08:17:00  Agrani Smart Banking App

# %%
df.to_csv('/content/drive/My Drive/banking_review_spl3/all_banking_app_reviews.csv', index=False)

# %%
df.shape
# Out:
# (78938, 4)
